# %% [markdown]
# # Terminology project
#
# ## **Spacy trainable pipe**
#
# ### AGUIAR Mathilde NIAOURI Dimitra
#
# #### M2 NLP

# %% [markdown]
# # Goal and tools

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### Imports and packages

# %%
# !pip3 install 'spacy==3.4.3'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#!python -m spacy download en_core_web_sm
#!pip install spacy-transformers

## Uncomment if you want to download one of the following model
# !python -m spacy download en_core_web_md
# !python -m spacy download en_core_web_lg
#!python -m spacy download en_core_web_trf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 42.8 MB 324 kB/s
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
import spacy
import fnmatch
import os
import re
from os import path, walk
import shutil
import glob
import pandas as pd
from spacy.scorer import Scorer
from spacy.training import Example
from spacy.tokens import Doc

# %% [markdown]
# Downloading the curated dataset

# %%
# !wget https://raw.githubusercontent.com/MathildeAguiar/terminology_project/tree/main/data

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Helpers to find files and create folders

# %%
def create_folder(path):
    """Create a folder if it doesn't already exist"""
    if not os.path.isdir(path):
        os.makedirs(path)
    return


def find_files(directory, pattern='*.final'):
    """Recursively finds all files matching the pattern."""
    files = []
    for root, dirnames, filenames in walk(directory):
        for filename in fnmatch.filter(filenames, pattern):
            files.append(path.join(root, filename))
    # sort the list, to avoid mismatch in the output files
    files = sorted(files)
    return files

# %% [markdown]
# Adapt the format of the IOB tags to be supported by Spacy. Spacy expects tags in the following format:
# ```
# B-ATTRIBUTE
# ```
# So we convert the `B` into `B-NLP` and the `I` to `I-NLP`.

# %%
def mapper(token):
  """
  Adapts the tags into a Spacy readable format
  """
  if token == "B":
    return "B-NLP"
  elif token == "I":
    return "I-NLP"
  else: 
    return token

# %%
# !mkdir /content/drive/MyDrive/Terminology_project/curated/training_data/iob_md 
# !mkdir /content/drive/MyDrive/Terminology_project/curated/dev_data/iob_md

# %%
def retag_files():   
    """ 
    Retag the original .final files by using the Spacy tag format.
    Save the result into a .iob file.    
    """
    # First process the training files
    directory_tg_train = "/content/drive/MyDrive/Terminology_project/curated/training_data/"
    all_training_files = find_files(directory_tg_train) 
    for f in all_training_files:
        with open(f, mode='r', encoding='utf-8') as myfile:
            lines = myfile.readlines()
            tmp = re.findall('\d{4}-\S*', f)
            iob_file_name = directory_tg_train+"iob_md/"+tmp[0].split(".")[0]+".iob"
            new_file = open(iob_file_name, "a")
            for l in lines:
              if not l.isspace():
                words = l.split()
                new_array = list(map(mapper, words))
                if len(new_array)>1:
                    new_txt = new_array[0]+"\t"+new_array[1]+"\n"
                elif len(new_array)>0:
                    new_txt = new_array[0]+"\n"
                else: continue  
                new_file.write(new_txt)
            new_file.close()

    # 2nd process the dev files
    directory_tg_dev = "/content/drive/MyDrive/Terminology_project/curated/dev_data/"
    all_dev_files = find_files(directory_tg_dev)
    for f in all_dev_files:
        with open(f, mode='r', encoding='utf-8') as myfile:
            lines = myfile.readlines()
            tmp = re.findall('\d{4}-\S*', f)
            iob_file_name = directory_tg_dev+"iob_md/"+tmp[0].split(".")[0]+".iob"
            new_file = open(iob_file_name, "a")
            for l in lines:
              if not l.isspace():
                words = l.split()
                new_array = list(map(mapper, words))
                if len(new_array)>1:
                    new_txt = new_array[0]+"\t"+new_array[1]+"\n"
                elif len(new_array)>0:
                    new_txt = new_array[0]+"\n"
                else: continue
                new_file.write(new_txt)
            new_file.close()

# %%
retag_files()

# %% [markdown]
# ### Convert the IOB files into *.spacy* binary files

# %%
# !mkdir /content/drive/MyDrive/Terminology_project/curated/training_data/iob_md/output 
# !mkdir /content/drive/MyDrive/Terminology_project/curated/dev_data/iob_md/output

# %%
## For the training set ##
# Uncomment the line you want in function of the model you are using 
# !python -m spacy convert -c iob -s -n 10000 -b en_core_web_md /content/drive/MyDrive/Terminology_project/curated/training_data/iob_md /content/drive/MyDrive/Terminology_project/curated/training_data/iob_md/output

#!python -m spacy convert -c iob -s -n 10000 -b en_core_web_md /curated/training_data/iob /curated/training_data/iob/output
#!python -m spacy convert -c iob -s -n 10000 -b en_core_web_lg /curated/training_data/iob /curated/training_data/iob/output
#!python -m spacy convert -c iob -s -n 10000 -b en_core_web_trf /curated/training_data/iob /curated/training_data/iob/output
# Out:
# ℹ Auto-detected token-per-line NER format
# ℹ Grouping every 10000 sentences into a document.
# ℹ Segmenting sentences with parser from model 'en_core_web_md'.
# ✔ Generated output file (1 documents):
# /content/drive/MyDrive/Terminology_project/curated/training_data/iob_md/output/2009-35-1-29-46.spacy
# ℹ Grouping every 10000 sentences into a document.
# ℹ Segmenting sentences with parser from model 'en_core_web_md'.
# ✔ Generated output file (1 documents):
# /content/drive/MyDrive/Terminology_project/curated/training_data/iob_md/output/2009-35-1-3-28.spacy
# ℹ Grouping every 10000 sentences into a document.
# ℹ Segmenting sentences with parser from model 'en_core_web_md'.
# ✔ Generated output file (1 documents):
# /content/drive/MyDrive/Terminology_project/curated/training_data/iob_md/output/2009-35-1-47-59.spacy
# ℹ Grouping every 10000 sentences into a document.
# ℹ Segmenting sentences with parser from model 'en_core_web_md'.
# ✔ Generated output file (1 documents):
# ...

# %%
## For the dev set ##
# Uncomment the line you want in function of the model you are using 
# !python -m spacy convert -c iob -s -n 10000 -b en_core_web_md /content/drive/MyDrive/Terminology_project/curated/dev_data/iob_md /content/drive/MyDrive/Terminology_project/curated/dev_data/iob_md/output

#!python -m spacy convert -c iob -s -n 10000 -b en_core_web_md /curated/dev_data/iob /curated/dev_data/iob/output
#!python -m spacy convert -c iob -s -n 10000 -b en_core_web_lg /curated/dev_data/iob /curated/dev_data/iob/output
#!python -m spacy convert -c iob -s -n 10000 -b en_core_web_trf /curated/dev_data/iob /curated/dev_data/iob/output
# Out:
# ℹ Auto-detected token-per-line NER format
# ℹ Grouping every 10000 sentences into a document.
# ℹ Segmenting sentences with parser from model 'en_core_web_md'.
# ✔ Generated output file (1 documents):
# /content/drive/MyDrive/Terminology_project/curated/dev_data/iob_md/output/2009-35-4-597-635.spacy
# ℹ Grouping every 10000 sentences into a document.
# ℹ Segmenting sentences with parser from model 'en_core_web_md'.
# ✔ Generated output file (1 documents):
# /content/drive/MyDrive/Terminology_project/curated/dev_data/iob_md/output/2010-36-1-1-30.spacy
# ℹ Grouping every 10000 sentences into a document.
# ℹ Segmenting sentences with parser from model 'en_core_web_md'.
# ✔ Generated output file (1 documents):
# /content/drive/MyDrive/Terminology_project/curated/dev_data/iob_md/output/2011-37-3-421-454.spacy
# ℹ Grouping every 10000 sentences into a document.
# ℹ Segmenting sentences with parser from model 'en_core_web_md'.
# ✔ Generated output file (1 documents):
# ...

# %% [markdown]
# # Training the pipeline
#
# First convert the base-config into a config file and then simply using the command line `spacy train`

# %%
# If the GPU is available run this cell 
# !python -m spacy init fill-config /content/drive/MyDrive/Terminology_project/base_config_ner_only.cfg config.cfg
# Out:
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# !mkdir /content/drive/MyDrive/Terminology_project/output_clean_md
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/Terminology_project/output_clean_md’: File exists

# %% [markdown]
# Test if there is a GPU available

# %%
gpu = spacy.prefer_gpu()
print(gpu)
# Out:
# True

# %% [markdown]
# If it returns False please run this command and re run the previous cell.

# %%
# !python -m spacy train --gpu-id 0 /content/config.cfg --output /content/drive/MyDrive/Terminology_project/output_clean_md --paths.train /content/drive/MyDrive/Terminology_project/curated/training_data/iob_md/output --paths.dev /content/drive/MyDrive/Terminology_project/curated/dev_data/iob_md/output
# Out:
# ℹ Saving to output directory:
# /content/drive/MyDrive/Terminology_project/output_clean_md
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2022-12-11 15:25:20,802] [INFO] Set up nlp object from config
# INFO:spacy:Set up nlp object from config
# [2022-12-11 15:25:20,812] [INFO] Pipeline: ['tok2vec', 'ner']
# INFO:spacy:Pipeline: ['tok2vec', 'ner']
# [2022-12-11 15:25:20,816] [INFO] Created vocabulary
# INFO:spacy:Created vocabulary
# [2022-12-11 15:25:20,817] [INFO] Finished initializing nlp object
# INFO:spacy:Finished initializing nlp object
# [2022-12-11 15:25:33,294] [INFO] Initialized pipeline components: ['tok2vec', 'ner']
# INFO:spacy:Initialized pipeline components: ['tok2vec', 'ner']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ...

# %% [markdown]
# You should obtain 2 models: `model-best` and `model-base`. To test the trained Pipeline it's better to use `model-best`.

# %% [markdown]
# # Testing on the test dataset

# %% [markdown]
# Using Spacy `Scorer`

# %% [markdown]
# ### Preprocessinf the test files
#
# Reconstructing the sentences

# %%
# !mkdir /content/drive/MyDrive/Terminology_project/curated/test_data/iob_md

# %%
def retag_test_files():
    """ 
    Retag the original .final files by using the Spacy tag format.
    Save the result into a .iob file.    
    """
    # First process the test files
    directory_tg_test = "/content/drive/MyDrive/Terminology_project/curated/test_data/"  
    all_test_files = glob.glob(directory_tg_test + "/*.final")
    for f in all_test_files:
        with open(f, mode='r', encoding='utf-8') as myfile:
            lines = myfile.readlines()
            tmp = re.findall('\d{4}-\S*', f)
            iob_file_name = directory_tg_test+"iob_md/"+tmp[0].split(".")[0]+".iob"
            new_file = open(iob_file_name, "a")
            for l in lines:
              if not l.isspace():
                words = l.split()
                new_array = list(map(mapper, words))
                if len(new_array)>1:
                    new_txt = new_array[0]+"\t"+new_array[1]+"\n"
                elif len(new_array)>0:
                    new_txt = new_array[0]+"\n"
                else: continue  
                new_file.write(new_txt)
            new_file.close()

# %%
retag_test_files()

# %%
path = r'/content/drive/MyDrive/Terminology_project/curated/test_data/iob_md'
all_files = glob.glob(path + "/*.iob")

l = []
cols = ['Token', 'Tag']

for filename in all_files:
    df = pd.read_csv(filename, names = cols,on_bad_lines='skip', sep='\s+', engine='python')
    l.append(df)

# Our tokens from test set are stored in a Dataframe
test_df = pd.concat(l, axis=0, ignore_index=True)

# drop nan values
test_df = test_df.dropna()
test_df['Token'].fillna('', inplace=True)

# %%
test_df.head()
test_df.iloc[88]
print(len(test_df['Token']))
print(len(test_df['Tag']))
# Out:
# 2772
# 2772

# %% [markdown]
# ### Using the command line

# %%
# !mkdir /content/drive/MyDrive/Terminology_project/curated/test_data/iob_md/output

# %%
# !python -m spacy convert -c iob -s -n 10000 -b en_core_web_md /content/drive/MyDrive/Terminology_project/curated/test_data/iob_md /content/drive/MyDrive/Terminology_project/curated/test_data/iob_md/output
# Out:
# ℹ Auto-detected token-per-line NER format
# ℹ Grouping every 10000 sentences into a document.
# ℹ Segmenting sentences with parser from model 'en_core_web_md'.
# ✔ Generated output file (1 documents):
# /content/drive/MyDrive/Terminology_project/curated/test_data/iob_md/output/2009-35-4-559-595.spacy
# ℹ Grouping every 10000 sentences into a document.
# ℹ Segmenting sentences with parser from model 'en_core_web_md'.
# ✔ Generated output file (1 documents):
# /content/drive/MyDrive/Terminology_project/curated/test_data/iob_md/output/2010-36-1-31-69.spacy
# ℹ Grouping every 10000 sentences into a document.
# ℹ Segmenting sentences with parser from model 'en_core_web_md'.
# ✔ Generated output file (1 documents):
# /content/drive/MyDrive/Terminology_project/curated/test_data/iob_md/output/2011-37-3-455-488.spacy
# ℹ Grouping every 10000 sentences into a document.
# ℹ Segmenting sentences with parser from model 'en_core_web_md'.
# ✔ Generated output file (1 documents):
# ...

# %%
# !python -m spacy evaluate --gpu-id 0 /content/drive/MyDrive/Terminology_project/output_clean_md/model-best /content/drive/MyDrive/Terminology_project/curated/test_data/iob_md/output
# Out:
# ℹ Using GPU: 0
#
# ================================== Results ==================================
#
# TOK     -
# NER P   57.23
# NER R   54.82
# NER F   56.00
# SPEED   4611
#
#
# =============================== NER (per type) ===============================
#
#           P       R       F
# NLP   57.23   54.82   56.00
